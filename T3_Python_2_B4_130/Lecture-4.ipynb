# %%
import requests
def current_weather():
    api_key="c096eadd3c5a43663bee27c7c3b53a05"
    city=input("Enter the City name: ")
    request_url=f"http://api.openweathermap.org/geo/1.0/direct?q={city}&appid={api_key}"
    response=requests.get(request_url)
    coordinates=response.json()
    lat=coordinates[0]["lat"]
    lon=coordinates[0]["lon"]
    request_url1=f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={api_key}"
    response1=requests.get(request_url1)
    weather_data=response1.json();
    print(json.dumps(weather_data,indent=5))
    des=weather_data["weather"][0]["description"]
    tem=weather_data["main"]["temp"]
    pre=weather_data["main"]["pressure"]
    hum=weather_data["main"]["humidity"]
    vis=weather_data["visibility"]
    ws=weather_data["wind"]["speed"]
    print("***************************************************************************************************************************************")
    print("***************************************************************************************************************************************")
    print(f"Description : {des}")
    print(f"Temprature  : {tem}")
    print(f"Pressure    : {pre}")
    print(f"Humidity    : {hum}")
    print(f"Visibility  : {vis}")
    print(f"Wind Speed  : {ws}")
current_weather()
# Out:
# Enter the City name:  Rajkot
# {
#      "coord": {
#           "lon": 70.8028,
#           "lat": 22.3053
#      },
#      "weather": [
#           {
#                "id": 800,
#                "main": "Clear",
#                "description": "clear sky",
#                "icon": "01d"
#           }
#      ],
#      "base": "stations",
#      "main": {
#           "temp": 307.11,
#           "feels_like": 312.86,
#           "temp_min": 307.11,
#           "temp_max": 307.11,
#           "pressure": 1010,
#           "humidity": 54,
#           "sea_level": 1010,
#           "grnd_level": 993
#      },
#      "visibility": 10000,
#      "wind": {
#           "speed": 5.93,
#           "deg": 247,
#           "gust": 6.67
#      },
#      "clouds": {
#           "all": 0
#      },
#      "dt": 1779767164,
#      "sys": {
#           "type": 2,
#           "id": 2104500,
#           "country": "IN",
#           "sunrise": 1779755620,
#           "sunset": 1779803655
#      },
# ...

# %%
import requests
def current_weather():
    api_key="c096eadd3c5a43663bee27c7c3b53a05"
    city=input("Enter the City name: ")
    request_url=f"http://api.openweathermap.org/geo/1.0/direct?q={city}&appid={api_key}"
    response=requests.get(request_url)
    coordinates=response.json()
    lat=coordinates[0]["lat"]
    lon=coordinates[0]["lon"]
    request_url1=f"http://api.openweathermap.org/data/2.5/air_pollution?lat={lat}&lon={lon}&appid={api_key}"
    response1=requests.get(request_url1)
    weather_data=response1.json();
    print(json.dumps(weather_data,indent=5))
    q_index={1:"Good",2:"Fair",3:"Moderate",4:"Poor",5:"Very Poor"}
    a=weather_data['list'][0]["main"]["aqi"]
    print(q_index[a])
current_weather()
# Out:
# Enter the City name:  Rajkot
# {
#      "coord": {
#           "lon": 70.8028,
#           "lat": 22.3053
#      },
#      "list": [
#           {
#                "main": {
#                     "aqi": 1
#                },
#                "components": {
#                     "co": 93.47,
#                     "no": 0.16,
#                     "no2": 0.64,
#                     "o3": 36.42,
#                     "so2": 0.48,
#                     "pm2_5": 6.17,
#                     "pm10": 19.5,
#                     "nh3": 0.45
#                },
#                "dt": 1779768089
#           }
#      ]
# }
# Good

# %%
import requests
def fivedays():
    api_key="c096eadd3c5a43663bee27c7c3b53a05"
    city=input("Enter the City name: ")
    request_url=f"http://api.openweathermap.org/geo/1.0/direct?q={city}&appid={api_key}"
    response=requests.get(request_url)
    coordinates=response.json()
    lat=coordinates[0]["lat"]
    lon=coordinates[0]["lon"]
    request_url1=f"http://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={api_key}"
    response1=requests.get(request_url1)
    weather_data=response1.json();
    print(json.dumps(weather_data,indent=5))
    return weather_data
five_days=fivedays()
# Out:
# Enter the City name:  Rajkot
# {
#      "cod": "200",
#      "message": 0,
#      "cnt": 40,
#      "list": [
#           {
#                "dt": 1779775200,
#                "main": {
#                     "temp": 308.38,
#                     "feels_like": 311.77,
#                     "temp_min": 308.38,
#                     "temp_max": 309.82,
#                     "pressure": 1009,
#                     "sea_level": 1009,
#                     "grnd_level": 992,
#                     "humidity": 43,
#                     "temp_kf": -1.44
#                },
#                "weather": [
#                     {
#                          "id": 800,
#                          "main": "Clear",
#                          "description": "clear sky",
#                          "icon": "01d"
#                     }
#                ],
#                "clouds": {
#                     "all": 0
#                },
#                "wind": {
#                     "speed": 5.28,
# ...

# %%
import pandas as pd
data={"Date_Time":[],"Description":[],"Temp":[],"Pressure":[],"Humidity":[],"Visibility":[],"Wind Speed":[]}
for i in five_days["list"]:
    data["Date_Time"].append(i['dt_txt'])
    data["Description"].append(i["weather"][0]["description"])
    data["Temp"].append(i["main"]["temp"])
    data["Pressure"].append(i["main"]["pressure"])
    data["Humidity"].append(i["main"]["humidity"])
    data["Visibility"].append(i["visibility"])
    data["Wind Speed"].append(i["wind"]["speed"])
df=pd.DataFrame(data)
df
# Out:
#               Date_Time       Description    Temp  Pressure  Humidity  \
# 0   2026-05-26 06:00:00         clear sky  308.38      1009        43
# 1   2026-05-26 09:00:00         clear sky  311.89      1006        30
# 2   2026-05-26 12:00:00         clear sky  312.06      1005        30
# 3   2026-05-26 15:00:00         clear sky  306.92      1007        45
# 4   2026-05-26 18:00:00         clear sky  303.49      1008        60
# 5   2026-05-26 21:00:00         clear sky  301.84      1007        70
# 6   2026-05-27 00:00:00         clear sky  300.70      1008        79
# 7   2026-05-27 03:00:00         clear sky  303.41      1010        59
# 8   2026-05-27 06:00:00         clear sky  310.69      1009        26
# 9   2026-05-27 09:00:00         clear sky  314.47      1006        19
# 10  2026-05-27 12:00:00         clear sky  312.39      1005        27
# 11  2026-05-27 15:00:00         clear sky  307.29      1007        43
# ...

# %% [markdown]
# NASA_API="svXCSVzhsIyVwA0utEJcyae6EPZhUDgnW5fShYGt"

# %%
import requests
url="https://api.nasa.gov/planetary/apod"
response=requests.get(url,params={"api_key":"svXCSVzhsIyVwA0utEJcyae6EPZhUDgnW5fShYGt",
                                 "date":"2026-05-26"})
data=response.json()
print(data["url"])
# Out:
# https://apod.nasa.gov/apod/image/2605/Ngc3660Burcin_Block_960.jpg

# %%
import requests
url="https://api.nasa.gov/planetary/apod"
response=requests.get(url,params={"api_key":"svXCSVzhsIyVwA0utEJcyae6EPZhUDgnW5fShYGt",
                                 "count":10})
data=response.json()
for i in data:
    print(i["url"])
# Out:
# https://apod.nasa.gov/apod/image/2009/VenusClouds_Akatzuki_960.jpg
# https://apod.nasa.gov/apod/image/shapley1_aat.gif
# https://apod.nasa.gov/apod/image/0907/m94crop_Paciorek.jpg
# https://apod.nasa.gov/apod/image/0112/leonids_kwon.jpg
# https://apod.nasa.gov/apod/image/2005/SWAN1_perrot.jpg
# https://apod.nasa.gov/apod/image/1403/blackhole_hobart_960.jpg
# https://apod.nasa.gov/apod/image/2309/BeautNishimura_Horalek_960.jpg
# https://apod.nasa.gov/apod/image/0312/protonaurora_image_big.jpg
# https://apod.nasa.gov/apod/image/2512/MontesCaucasusCopie1024.png
# https://apod.nasa.gov/apod/image/9611/fractaldust_elw.gif

# %%
import requests
url="https://api.nasa.gov/planetary/apod"
response=requests.get(url,params={"api_key":"svXCSVzhsIyVwA0utEJcyae6EPZhUDgnW5fShYGt",
                                 "count":10})
data=response.json()
dates=[]
url=[]
for i in data:
    dates.append(i["date"])
    url.append(i["url"])
df=pd.DataFrame({"Date":dates,"URL":url})
df
# Out:
#          Date                                                URL
# 0  2009-03-26  https://apod.nasa.gov/apod/image/0903/m46n2438...
# 1  2012-03-15  https://apod.nasa.gov/apod/image/1203/GraySun2...
# 2  2015-06-14  https://apod.nasa.gov/apod/image/1506/m101_Hub...
# 3  1997-04-08  https://apod.nasa.gov/apod/image/9704/halebopp...
# 4  2006-11-06  https://apod.nasa.gov/apod/image/0611/swan_gra...
# 5  2006-05-24  https://apod.nasa.gov/apod/image/0605/quasar5p...
# 6  2021-05-27  https://apod.nasa.gov/apod/image/2105/TLEMay20...
# 7  2005-11-10  https://apod.nasa.gov/apod/image/0511/gravtug_...
# 8  2004-09-25  https://apod.nasa.gov/apod/image/0409/feii_eit...
# 9  2013-06-16  https://apod.nasa.gov/apod/image/1306/apod18_l...
